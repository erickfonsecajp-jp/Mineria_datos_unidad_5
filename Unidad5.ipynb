# %% [markdown]
# <div align="center">
#
# ### Desarrollo Actividad Unidad 5
# ### Minería de Datos
# **(Evaluación de Herramientas: WEKA, KNIME, Orange y RapidMiner)**
#
# **Estudiante:** Erick Jefferson Fonseca Peña
# **Docente:** Jorge Ignacio Blanco
# **Programa:** Ingeniería Industrial
# **Universidad:** Católica de Colombia
# **Año:** 2025
# </div>

# %% [markdown]
# ### 1. Objetivos de la Actividad
# - Elaborar un cuadro comparativo de herramientas de minería de datos.
# - Crear un análisis de eficiencia.
# - Asociar cada herramienta con 5 empresas reales.
# - Me permite generar el siguiente producto de entrega en formato .html

# %% [markdown]
# ### 2. Cuadro Comparativo de Herramientas
# Ejemplo de criterios para la tabla:
# - Licencia
# - Facilidad de uso
# - Funciones principales
# - Ventajas y desventajas
# - Usuarios ideales
#
# - *Aspectos de forma: se agregan colores a las columnas, se deja centrado el contenido y los encabezados, ademas dejar lineas negras en los bordes*

# %%
import pandas as pd 

# Definir el DataFrame con los datos del cuadro comparativo
herramientas = pd.DataFrame({
    'Herramienta': ['WEKA', 'KNIME', 'Orange', 'RapidMiner'],
    'Licencia': ['GPL', 'GPL', 'GPL', 'GPL'],
    'Facilidad de uso': [
        'Fácil de usar, adecuada para principiantes',
        'Curva de aprendizaje moderada, pero flexible',
        'Muy intuitiva y fácil de usar',
        'Interfaz gráfica intuitiva, pero compleja para principiantes'
    ],
    'Funciones principales': [
        'Clasificación y regresión\nAgrupación y asociacion de datos\nVisualizacion de datos\nPreprocesamiento de datos\nAnalisis de modelos (validacion cruzada, evaluación de precisión)',
        'Diseño de flujos de trabajo\nIntegracion de datos y análisis avanzados\nModelado predictivo y no supervisado\nPreprocesamiento y manipulación de datos\nVisualización de resultados y evaluación de modelos',
        'Análisis interactivo de datos\nVisualización interactiva\nAprendizaje automático con varios algoritmos\nPreprocesamiento y transformacion de datos\nModelado con widgets gráficos',
        'Análisis de datos y minería de datos\nModelado predictivo (clasificación, regresresión)\nPreprocesamiento avanzado de datos\nVisualización gráfica de resultados\nSoporte para Big Data y Hadoop'
    ],
    'Ventajas': [
        'Interfaz sencilla y clara\nGran cantidad de algoritmos para clasificacion y regresión\nAmpliamente utilizado en el ámbito académico',
        'Potente para Big Data y análisis a gran escala\nAltamente extensible con nodos personalizados\nBuen soporte para integracion de flujos de trabajo complejos',
        'Interfaz grafica altamente visual\nExtensible con scripts en Python\nFacil de usar, ideal para educación y prototipos rápidos',
        'Extensible y agnóstica (compatible con diversas tecnologías)\nGran comunidad de usuarios y recursos educativos\nSoporte para integracion con herramientas externas'
    ],
    'Desventajas': [
        'Limitada capacidad para trabajar con Big Data\nLa interfaz gráfica puede ser algo simple para usuarios avanzados',
        'Requiere tiempo para dominar los flujos de trabajo y la interfaz\nCurva de aprendizaje más empinada para usuarios novatos debido a la complejidad de la interfaz gráfica',
        'Menor escalabilidad para grandes proyectos\nAlgunas funciones avanzadas son limitadas o requieren conocimientos técnicos adicionales',
        'Puede ser complejo para nuevos usuarios\nRequiere recursos de hardware significativos para proyectos grandes'
    ]
})

# Estilo por columnas
def color_columns(s):
    color_map = {
        'Herramienta': 'background-color: #f2f2f2; color: black; text-align: center;',
        'Licencia': 'background-color: lightblue; color: black; text-align: center;',
        'Facilidad de uso': 'background-color: lightgreen; color: black; text-align: center;',
        'Funciones principales': 'background-color: lightyellow; color: black; text-align: center;',
        'Ventajas': 'background-color: lightcoral; color: black; text-align: center;',
        'Desventajas': 'background-color: lightgrey; color: black; text-align: center;'
    }
    return [color_map.get(s.name, 'text-align: center; color: black;')] * len(s)

# Aplicar estilos
styled_herramientas = (
    herramientas.style
        .apply(color_columns, axis=0)
        .set_properties(**{      # Bordes para celdas
            'border': '1px solid black',
            'text-align': 'center'
        })
        .set_table_styles([      # Bordes para encabezados
            {'selector': 'th', 'props': [
                ('text-align', 'center'),
                ('border', '1px solid black'),
                ('background-color', '#d9d9d9'),
                ('color', 'black')
            ]}
        ])
)

styled_herramientas
# Out:
# <style type="text/css">
# #T_292e7 th {
#   text-align: center;
#   border: 1px solid black;
#   background-color: #d9d9d9;
#   color: black;
# }
# #T_292e7_row0_col0, #T_292e7_row1_col0, #T_292e7_row2_col0, #T_292e7_row3_col0 {
#   background-color: #f2f2f2;
#   color: black;
#   text-align: center;
#   border: 1px solid black;
#   text-align: center;
# }
# #T_292e7_row0_col1, #T_292e7_row1_col1, #T_292e7_row2_col1, #T_292e7_row3_col1 {
#   background-color: lightblue;
#   color: black;
#   text-align: center;
#   border: 1px solid black;
#   text-align: center;
# }
# #T_292e7_row0_col2, #T_292e7_row1_col2, #T_292e7_row2_col2, #T_292e7_row3_col2 {
#   background-color: lightgreen;
#   color: black;
#   text-align: center;
#   border: 1px solid black;
#   text-align: center;
# }
# #T_292e7_row0_col3, #T_292e7_row1_col3, #T_292e7_row2_col3, #T_292e7_row3_col3 {
#   background-color: lightyellow;
#   color: black;
#   text-align: center;
#   border: 1px solid black;
# ...

# %% [markdown]
# ### 3. Análisis de Eficiencia
#
# Se coloca el sigueinte codigo para generar una tabla donde se puede evaluar como se comporta cada una de estas herramientas de datos, considerando su rendimiento técnico, la facilidad de aprendizaje y uso, y la aplicabilidad práctica en distintos escenarios.

# %%
import pandas as pd

# Mostrar texto completo y ampliar ancho de la tabla
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 2000)

# Crear DataFrame
analisis = pd.DataFrame({
    'Herramienta': ['WEKA', 'KNIME', 'Orange', 'RapidMiner'],
    
    'Rendimiento': [
        'Posee un adecuado rendimiento con datasets de pequeños y medianos datos. No es ideal para Big Data.Adecuado para algoritmos clásicos.',
        'Excelente rendimiento en flujos complejos y grandes volúmenes de datos. Compatible con Big Data. Cuenta con una estructura profesional.',
        'Rendimiento moderado. No es apto para Big Data. Procesamient más lento con datasets grandes.',
        'Muy alto rendimiento. Capaz de manejar Big Data y procesos complejos. Optimiza los empresariales y de produccion.'
    ],
    
    'Facilidad de uso': [
        'Adecuado para uso de principiantes. Cuenta con interfaz simple sin embargo poco visual. Es limitado para flujos complejos.',
        'Curva de aprendizaje moderada. Muy flexible y potente una vez dominado. Interfaz basada en nodos.',
        'Adaptable e intuitiva y visual. Ideal para principiantes.',
        'Es una Interfaz potente pero más compleja. Curva de aprendizaje media-alta. Ofrece ayuda guiada.'
    ],
    
    'Aplicabilidad según caso de uso': [
        'Es ideal para educacion, experimentacióon y analisis academico. No se recomendado para grandes volumenes de datos o uso empresarial.',
        'Perfecto para empresas, analisis de datos complejos e integración de datos. No es adecuado para usuarios sin experiencia.',
        'Cuenta con adeucadas herramientas de visualizacion, enseñanza y prototipos rápidos. No es apto en cadenas producción o grandes proyectos.',
        'Es Ideal para empresas, minería de datos avanzada y automatización. No recomendado para equipos con pocos recursos.'
    ]
})

# Aplicar centrado a TODAS las columnas
analisis_style = analisis.style.set_properties(**{
    'text-align': 'center'
}).set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'center')]}
])

# Mostrar sin índice
analisis_style.hide(axis='index')
# Out:
# <style type="text/css">
# #T_d59f8 th {
#   text-align: center;
# }
# #T_d59f8_row0_col0, #T_d59f8_row0_col1, #T_d59f8_row0_col2, #T_d59f8_row0_col3, #T_d59f8_row1_col0, #T_d59f8_row1_col1, #T_d59f8_row1_col2, #T_d59f8_row1_col3, #T_d59f8_row2_col0, #T_d59f8_row2_col1, #T_d59f8_row2_col2, #T_d59f8_row2_col3, #T_d59f8_row3_col0, #T_d59f8_row3_col1, #T_d59f8_row3_col2, #T_d59f8_row3_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_d59f8">
#   <thead>
#     <tr>
#       <th id="T_d59f8_level0_col0" class="col_heading level0 col0" >Herramienta</th>
#       <th id="T_d59f8_level0_col1" class="col_heading level0 col1" >Rendimiento</th>
#       <th id="T_d59f8_level0_col2" class="col_heading level0 col2" >Facilidad de uso</th>
#       <th id="T_d59f8_level0_col3" class="col_heading level0 col3" >Aplicabilidad según caso de uso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d59f8_row0_col0" class="data row0 col0" >WEKA</td>
# ...

# %% [markdown]
# ### 4. Empresas que Usan Cada Herramienta
# Se genera el sigueinte cuadro donde se relacionn las cinco empresas para cada herramienta y su respectivo caso de uso, en este caso use como consulta de informacion la IA quien me facilito las empresas que manejan estas herramientas, dado que no es facil conocer que herramientas de datos usa cada empresa.

# %%
import pandas as pd

# Ajustes para que no se vea apeñuzcado
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 3000)
pd.set_option('display.max_columns', None)

# Tabla de empresas que usan cada herramienta
empresas = pd.DataFrame({

    'Herramienta': [
        'KNIME','KNIME','KNIME','KNIME','KNIME',
        'RapidMiner','RapidMiner','RapidMiner','RapidMiner','RapidMiner',
        'WEKA','WEKA','WEKA','WEKA','WEKA',
        'Orange','Orange','Orange','Orange','Orange'
    ],

    'Empresa': [
        'Siemens', 'Novartis', 'Deutsche Telekom', 'Continental', 'Johnson & Johnson',
        'BMW', 'Hewlett Packard Enterprise', 'Sanofi', 'EZCater', 'Sony',
        'Pentaho Corporation', 'Universidad de Waikato', 'MIT Research Labs', 'IBM Academic Programs', 'Stanford AI Lab',
        'Universidad de Ljubljana', 'Institutos Biomédicos Europeos', 'UC Irvine Research Group', 'Bioinformatics Labs', 'Harvard Medical School'
    ],

    'Caso de uso': [
        'Análisis de datos industriales y manufactura.',
        'Investigación farmacéutica y análisis de datos clínicos.',
        'Telecomunicaciones y análisis de redes.',
        'Automotriz: producción, calidad y logística.',
        'Análisis de datos clínicos y manufactura farmacéutica.',

        'Análisis predictivo en procesos automotrices.',
        'Minería de datos empresarial y analítica avanzada.',
        'Investigación clínica y modelado farmacológico.',
        'Optimización logística y predicción de demanda.',
        'Análisis de datos de manufactura y consumo.',

        'Minería de datos en herramientas BI.',
        'Investigación en machine learning.',
        'Ciencia de datos aplicada a educación e investigación.',
        'Programas académicos de analítica.',
        'Investigación avanzada en IA.',

        'Análisis exploratorio en educación e investigación.',
        'Bioinformática y visualización científica.',
        'Modelos para experimentos académicos.',
        'Investigación en datos biológicos.',
        'Visualización de datos médicos.'
    ],

    'Fuente bibliográfica': [
        'Edureka (Top 10 Data Analytics Tools).',
        'Edureka (Top 10 Data Analytics Tools).',
        'Edureka (Top 10 Data Analytics Tools).',
        'Edureka (Top 10 Data Analytics Tools).',
        'TICS Morelia (Herramientas Big Data).',

        'Edureka (Top 10 Data Mining Tools).',
        'Edureka (Top 10 Data Mining Tools).',
        'Edureka (Top 10 Data Mining Tools).',
        'Edureka (Top 10 Data Mining Tools).',
        'Grjenkin (Data Mining Tools).',

        'Wikipedia: WEKA (Machine Learning).',
        'Wikipedia: WEKA (Machine Learning).',
        'MIT AI Research Publications.',
        'IBM Academic Analytics Publications.',
        'Stanford AI Research Data Mining Group.',

        'Grjenkin (Data Mining Tools).',
        'ResearchGate Bioinformatics Studies.',
        'UC Irvine ML Repository Projects.',
        'Bioinformatics EU Laboratory Reports.',
        'Harvard Biomedical Data Projects.'
    ]
})

# Aplicar estilo centrado y sin índice
empresas_style = empresas.style.set_properties(
    **{'text-align': 'center'}
).set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'center'), ('font-weight', 'bold')]}
]).hide(axis='index')

empresas_style
# Out:
# <style type="text/css">
# #T_62c7a th {
#   text-align: center;
#   font-weight: bold;
# }
# ...

# %% [markdown]
# ## 5. Relación con CRISP-DM
# Explique cómo usar cada herramienta en cada etapa del modelo CRISP-DM.
#
# 🟢 WEKA ouede integrarse en las etapas centrales de CRISP-DM, teniendo en cuenta que permite explorar los datos mediante estadisticas no tan complejas y visualizaciones muy basicas, esta permite ofrece herramientas de limpieza y seleccion de atributos para la preparacion. Su mayor potencial esta en el modelado, ya que gracias a su amplia colección de algoritmos de clasificación, regresión y clustering. También permite con facilidad la evaluacion con mericas completas, validacion de datos cruzada y matrices de confusion, si apoyo en desarollo es limitado, aunque permite aplicar modelos.
#
# 🟡 Orange es ideal para las primeras etapas del CRISP-DM. permite facilitar la comprensión y exploración de los datos con visualizaciones intuitivas y widgets interactivos. Permite la preparacion de los datos mediante selección, limpieza y transformación sin programación. En el modelado ofrece algoritmos básicos de machine learning de forma visual, facilitanto la cadena o los flujos de las empresas, su validacion es sencilla a través de widgets comparativos. Sin embargo, su capacidad de despliegue es limitada no es recomendado en empresas dado que usa más para prototipos y enseñanza.
#
# 🟣 KNIME cubre eficazmente todas las etapas de CRISP-DM. Permite realizar y documentar el proceso, indispensable para los principios de auditoria y calidad, permite comprender los datos con estadísticas y visualizaciones avanzadas. Es fuerte en la preparacion de los datos, y permite la limpieza de los datos, integración y transformación, incluso en Big Data. Admite modelos de machine learning, Python, R y deep learning, util para proceso de produccion y servicios, su comportamiento es robusto y su mayor ventaja está en el despliegue, ya que permite automatizar flujos y publicar modelos en servidores.
#
# 🔴 RapidMiner es una herramienta muy completa alineada con todas las fases de CRISP-DM. Facilita definir objetivos, explorar datos y preparar información con numerosos operadores de limpieza y transformación. Permite construir modelos avanzados de manera visual y compararlos facilmente lo cual facilita la comprension de los procesos, flujos y relaciones de los datos,  ademas, ofrece capacidades empresariales fuertes en evaluación y, especialmente, en despliegue, donde permite automatizar procesos y publicar modelos listos para producción.

# %% [markdown]
# ## 5. Conclusiones:
#
#
# - El uso de la herramienta WEKA permite analizar modelos basicos y permite facilidad el proceso de aprendizaje, esta herramiena no se recomienda para Big Data ni flujos complejos, ademas es util para el proceso academico. No es usado muy usado en empresas grandes, dado que cuenta con roles mas de educacion
# - El uso de la herramienta KNIME permite el manejo de grandes volumenes de dato, permite el desarrollo de analisis complejos estadisticos y se adapta a ejercios de aprenizaje y entrenamiento.
# - El uso de la herramienta ORANGE es una herramienta mas robusta permite las interfaces de visualizacion de de los datos, permite adacptarte a la capacitacion y el análisis, pero es adaptable al usuario
# - El uso de RAPIDMINER es utlizado en empresas, lo cual permite tener y contar con un alto rendimiento, permite contar con flujos de analítica de datos mas complejos y su enfoque empresarial y de big data.
#
# Cualquiera de las herramientas gestoras de bases de datos es eficiente, sin embargo si es necesario saber para que empresa va dirigida de ello permitará establecer si son optimas de acuerdo al campo desarrollado, por ejemplo en produccion, entidades administraticas, farmacia, servicios, academicos o de investigacion.

# %% [markdown]
# ## Bibliografia
#
# Edureka. (2022). Top 10 data analytics tools. Edureka. https://www.edureka.co/blog/top-10-data-analytics-tools/
#
# Edureka. (2022). Top 10 data mining tools. Edureka. https://www.edureka.co/blog/top-10-data-mining-tools/
#
# Grjenkin. (2022). Make data work for you with these top data mining tools and techniques. Grjenkin Analytics Blog. https://grjenkin.com/articles/
#
# TICS Morelia. (2023). Herramientas Big Data más usadas en la actualidad. TICS Morelia. https://tics.morelia.gob.mx/
#
# University of Waikato. (2023). WEKA: Machine learning software in Java. Universidad de Waikato. https://www.cs.waikato.ac.nz/ml/weka/
#
# Wikipedia. (2023). Weka (aprendizaje automático). Wikipedia. https://es.wikipedia.org/wiki/Weka_(aprendizaje_autom%C3%A1tico)
#
# MIT Artificial Intelligence Laboratory. (2023). Applied machine learning research projects. MIT AI Lab.
#
# IBM Academic Research. (2023). Educational analytics and machine learning applications. IBM Research.
#
# Stanford Artificial Intelligence Laboratory. (2023). Data mining and discovery research. Stanford University.
#
# ResearchGate. (2023). Bioinformatics data analysis tools: Applications in scientific research. ResearchGate.
#
# University of California Irvine. (2023). Machine learning repository: Research projects and applications. UC Irvine.
#
# Harvard Medical School. (2023). Biomedical data visualization and analytics. Harvard University.
#
# European Bioinformatics Institute. (2023). Bioinformatics laboratory reports and analyses. EBI.
